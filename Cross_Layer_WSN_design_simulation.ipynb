# %%
#############################
# USER DEFINABLE PARAMETERS #
#############################

num_nodes = 20
area = 40000 # side length of a square area, in metres
server_location = [0, area/2] # set to be halfway up the left edge
power_increase = 3000 # amount each node increases its broadcast power for another broadcast, if it fails to find an available node.

# %%
#@title Default title text
import math
import random
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
from google.colab import files

################### 
# NETWORK DEVICES #
###################

class Server:
  global server_location
  global power_increase
  def __init__(self):
        self.location = server_location
        self.dist_to_server = [0,0]
        self.broadcast_dist = power_increase
        self.receiver_node = ''
        self.nodes_in_range = [] 
        self.request_node_location = ''
        self.message = ''
        self.data = 0
        self.stop_simulation = False
  
  # scan for nodes requesting connection
  def scan_for_requests(self):
    global broadcast_node_location
    # request received
    if self.request_node_location != '':
      # return own location
      for i in nodes:
        if i.location == self.request_node_location:
          i.nodes_in_range.append(self.location)
    # check to see if node is next broadcast node
    if (self.message != ''):
        x,y,data = self.message.split(' ')
        print('\n\nSERVER: package successfully received.\n')
        print(' Data: %s' % str(data))
        print('\n -- ENDING SIMULATION --.\n')
        self.stop_simulation = True
        
class Node:
  global single_sim_distances_unadj
  global single_sim_distances_adj
  global single_sim_route_distances

  def __init__(self, loc):
        self.location = loc
        self.dist_to_server = [0,0]
        self.broadcast_dist = power_increase
        self.receiver_node = ''
        self.nodes_in_range = [] 
        self.request_node_location = ''
        self.message = ''
        self.data = 0
        self.saved_broadcast_dist = 0
  
  # send location to any nodes in range
  def broadcast_request(self):
    print('\nNode %s: sending broadcast request . . .' % str(self.location))
    print('Broadcast distance: %dm' % self.broadcast_dist)
    for i in nodes:
      dist_node_i = get_distance(self.location, i.location)
      if (dist_node_i < self.broadcast_dist):
        i.request_node_location = self.location

        
  # scan for nodes requesting connection
  def scan_for_requests(self):
    # request received
    if self.request_node_location != '':
      # return own location
      for i in nodes:
        if i.location == self.request_node_location:
          i.nodes_in_range.append(self.location)
    global broadcast_node_location
    # check to see if node is next broadcast node
    if (self.message != '') and (self.location != broadcast_node_location):
      x,y,self.data = self.message.split(' ')
      self.data = int(self.data)
      if (x == str(self.location[0])) and (y == str(self.location[1])):
        print('\nNode %s: package successfully received.' % str(self.location))
        broadcast_node_location = self.location
        # not the best place for this but should work
        axs.plot(self.location[0], self.location[1], 'o', color='green', ms=7)
        self.request_node_location = ''
      


  def choose_recv_node(self):
    dist_A_to_server = get_distance(server_location, self.location)
    for i in self.nodes_in_range:
      dist_B_to_server = get_distance(server_location, i)
      if dist_B_to_server < dist_A_to_server:
        dist_A_to_server = dist_B_to_server
        self.receiver_node = i
    if self.receiver_node != '':
      global power_saved
      print('RECEIVER NODE SELECTED!:')
      print(' Location: %s' % str(self.receiver_node))
      print(' Distance to server: %.2fm away.' % get_distance(self.receiver_node, server_location))
      print(' Distance away: %.2fm.' % get_distance(self.location, self.receiver_node))
      # log unadjusted broadcast distance
      single_sim_distances_unadj.append(self.broadcast_dist)
      # set new adjusted broadcast dist
      self.broadcast_dist = get_distance(self.location, self.receiver_node)*1.1
      # log adjusted broadcast distance
      single_sim_distances_adj.append(self.broadcast_dist)
      print(' New broadcast distance: %dm' % self.broadcast_dist)
      # log actual distance to node
      single_sim_route_distances.append(get_distance(self.location, self.receiver_node))

      
  def send_data(self):
    packet = str(self.receiver_node[0]) + ' ' + str(self.receiver_node[1]) + ' ' + str(self.data)
    for i in self.nodes_in_range:
      temp_node = find_node(i)
      temp_node.message = packet
    print('\nNode %s: data has been broadcast.' % str(self.location))
    # clear buffers
    self.request_node_location = ''
    self.message = ''
    self.data = 0
    self.nodes_in_range = []
    global axs
    axs.plot([self.location[0], self.receiver_node[0]], [self.location[1], self.receiver_node[1]], color='green', linewidth=1)   
    

  def check_data_recv(self):
    if message != '':
      x,y,self.data = self.message.split(' ')
      if (x == self.location[0]) and (y == self.location[1]):
        broadcast_node_location = self.location

  def increase_distance(self):
    global power_increase
    self.broadcast_dist = self.broadcast_dist + power_increase

# %%
#############
# FUNCTIONS #
#############

# distance between two points
def get_distance(point_a, point_b):
  return math.sqrt((point_a[0] - point_b[0])**2 + (point_a[1] - point_b[1])**2)

# create randomly dispersed nodes
def create_nodes():
  global num_nodes
  global server_location
  for i in range(num_nodes):
    location = [int(random.random() * area), int(random.random() * area)]
    nodes.append(Node(location))  
    nodes[i].dist_to_server = get_distance(location, server_location)

#plot all nodes
def plot_nodes(my_plot):
  x_values = list(range(area))
  y_values = [None]*area
  # get y values
  for i in range(len(nodes)):
    x_val = nodes[i].location[0]
    y_values[x_val] = nodes[i].location[1]
    my_plot.plot(x_values, y_values, 'o', color='black',ms=7)
    my_plot.plot(0, area/2, marker='s', color='orange', ms=15)

# create source node
def assign_source_node(my_plot):
  global broadcast_node_location
  source_node = nodes[int(random.random()*num_nodes)]
  while(source_node.location[0] < area/2):
    source_node = nodes[int(random.random()*num_nodes)]
  source_node.data = 12345
  source_message = str(source_node.data) # no receiver node located yet to prepend data with
  my_plot.plot(source_node.location[0], source_node.location[1], 'o', color='limegreen', ms=10)
  broadcast_node_location = source_node.location

def find_node(location):
  for i in nodes:
    if i.location[0] == location[0]:
      return i

def run_idle_nodes():
  for i in nodes:
      # waiting nodes
      if i.location != broadcast_node_location:
        i.scan_for_requests()
  print('\n(Idle nodes run.)\n')

# %%
##############
# Simulation #
##############

#SIMULATION VARIABLES AND OBJECTS
nodes = []
broadcast_node_location = ''
fig, axl = plt.subplots(4, 4, figsize = (20, 20))
server = ''
broadcast_node = ''
source_node = ''

# LOGGING DATA
# for a single simulation
single_sim_distances_unadj = []
single_sim_route_distances = []
single_sim_distances_adj = []
# for all simulations (list of lists)
all_sim_distances_unadj = []
all_sim_route_distances = []
all_sim_distances_adj = []
# summary data for each simulation
sim_totals_broadcast_unadj = []
sim_totals_broadcast_adj = []
sim_totals_routes = []


# INITIALISATION #
def initialise_simulation():
  global server
  global broadcast_node
  global source_node
  global nodes
  global broadcast_node_location
  global power_saved
  global y_values

  broadcast_node_location = ''
  #server = ''
  #broadcast_node = ''
  nodes = []
  #source_node = ''

  create_nodes()
  # create plot
  #fig, axs = plt.subplots(1, 1)
  plot_nodes(axs)
  # create server
  server = Server()
  nodes.append(server)
  # Create source node
  source_node = assign_source_node(axs)
  # Assign as first broadcast node
  broadcast_node = find_node(broadcast_node_location)

# Run a Simulation round
def run_simulation():
  global server
  global broadcast_node
  global source_node
  global nodes

  while not server.stop_simulation:
    print("\n >> New Broadcast Node: %s <<" % str(broadcast_node.location))
    print('  Distance to server: %.2fm' % get_distance(broadcast_node.location, server_location))
        
    # Broadcast node runs this loop until it finds a receive node
    # Idle nodes continue to scan for transmission requests
    while broadcast_node.receiver_node == '':
      # update broadcast node
      broadcast_node = find_node(broadcast_node_location)
      # increase broadcast distance
      broadcast_node.increase_distance()
      # send broadcast request
      broadcast_node.broadcast_request()
      run_idle_nodes()
      # choose recv node is one is possible
      broadcast_node.choose_recv_node()
    # next node located, data sent, send buffer wiped
    # broadcast node location of simulator updated
    broadcast_node.send_data()
    run_idle_nodes()
    broadcast_node = find_node(broadcast_node_location)

######################################
# BEGIN: RUN 16 ROUNDS OF SIMULATION #
######################################
for i in range(4):
  for j in range(4):
    axs = axl[i,j]
    initialise_simulation()
    run_simulation()
    # store data for simulation round
    all_sim_distances_unadj.append(single_sim_distances_unadj)
    all_sim_distances_adj.append(single_sim_distances_adj)
    all_sim_route_distances.append(single_sim_route_distances)

    # clear data buffers
    single_sim_distances_adj = []
    single_sim_distances_unadj = []
    single_sim_route_distances = []

    axs.title.set_text('Simulation %d' % (1+j+(i*4)))


# CREATE SUMMARY DATA OF EACH SIMULATION
print("TOTALS:")
# calculate summaries
for i in range(len(all_sim_distances_unadj)):
  sim_totals_broadcast_unadj.append(sum(all_sim_distances_unadj[i]))
  sim_totals_broadcast_adj.append(sum(all_sim_distances_adj[i]))
  sim_totals_routes.append(sum(all_sim_route_distances[i]))

  print("Simulation %d:" % i)
  print('Unadjusted broadcast length: %.2f' % sim_totals_broadcast_unadj[i])
  print('Adjusted broadcast length: %.2f' % sim_totals_broadcast_adj[i])
  print('Actual route length: %.2f' % sim_totals_routes[i])
  


# SAVE RESULTS
if True: 
  filename = 'ELEC5514_simulation_output.png'
  plt.savefig(filename)
  files.download(filename)
# Out:
#  >> New Broadcast Node: [30122, 11546] <<
#   Distance to server: 31285.86m
#
# Node [30122, 11546]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [30122, 11546]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [28250, 17716]
#  Distance to server: 28342.18m away.
#  Distance away: 6447.73m.
#  New broadcast distance: 7092m
#
# Node [30122, 11546]: data has been broadcast.
#
# Node [28250, 17716]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [28250, 17716] <<
#   Distance to server: 28342.18m
#
# Node [28250, 17716]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [28250, 17716]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [28250, 17716]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [22771, 28063]
#  Distance to server: 24156.37m away.
#  Distance away: 11708.11m.
#  New broadcast distance: 12878m
#
# Node [28250, 17716]: data has been broadcast.
#
# Node [22771, 28063]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [22771, 28063] <<
#   Distance to server: 24156.37m
#
# Node [22771, 28063]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [22771, 28063]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [17631, 32895]
#  Distance to server: 21843.38m away.
#  Distance away: 7054.63m.
#  New broadcast distance: 7760m
#
# Node [22771, 28063]: data has been broadcast.
#
# Node [17631, 32895]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [17631, 32895] <<
#   Distance to server: 21843.38m
#
# Node [17631, 32895]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [17631, 32895]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [17631, 32895]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
#
# Node [17631, 32895]: sending broadcast request . . .
# Broadcast distance: 15000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [5997, 28017]
#  Distance to server: 10011.81m away.
#  Distance away: 12615.26m.
#  New broadcast distance: 13876m
#
# Node [17631, 32895]: data has been broadcast.
#
# Node [5997, 28017]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [5997, 28017] <<
#   Distance to server: 10011.81m
#
# Node [5997, 28017]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [5997, 28017]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [5997, 28017]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [0, 20000.0]
#  Distance to server: 0.00m away.
#  Distance away: 10011.81m.
#  New broadcast distance: 11012m
#
# Node [5997, 28017]: data has been broadcast.
#
#
# SERVER: package successfully received.
#
#  Data: 12345
#
#  -- ENDING SIMULATION --.
#
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [22586, 27078] <<
#   Distance to server: 23669.08m
#
# Node [22586, 27078]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [17444, 28237]
#  Distance to server: 19290.96m away.
#  Distance away: 5271.00m.
#  New broadcast distance: 5798m
#
# Node [22586, 27078]: data has been broadcast.
#
# Node [17444, 28237]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [17444, 28237] <<
#   Distance to server: 19290.96m
#
# Node [17444, 28237]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [15852, 27934]
#  Distance to server: 17726.65m away.
#  Distance away: 1620.58m.
#  New broadcast distance: 1782m
#
# Node [17444, 28237]: data has been broadcast.
#
# Node [15852, 27934]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [15852, 27934] <<
#   Distance to server: 17726.65m
#
# Node [15852, 27934]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [11913, 31253]
#  Distance to server: 16387.48m away.
#  Distance away: 5150.87m.
#  New broadcast distance: 5665m
#
# Node [15852, 27934]: data has been broadcast.
#
# Node [11913, 31253]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [11913, 31253] <<
#   Distance to server: 16387.48m
#
# Node [11913, 31253]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [11913, 31253]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [3627, 30195]
#  Distance to server: 10820.96m away.
#  Distance away: 8353.27m.
#  New broadcast distance: 9188m
#
# Node [11913, 31253]: data has been broadcast.
#
# Node [3627, 30195]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [3627, 30195] <<
#   Distance to server: 10820.96m
#
# Node [3627, 30195]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [3627, 30195]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [3627, 30195]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [0, 20000.0]
#  Distance to server: 0.00m away.
#  Distance away: 10820.96m.
#  New broadcast distance: 11903m
#
# Node [3627, 30195]: data has been broadcast.
#
#
# SERVER: package successfully received.
#
#  Data: 12345
#
#  -- ENDING SIMULATION --.
#
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [21046, 8008] <<
#   Distance to server: 24222.76m
#
# Node [21046, 8008]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [16400, 11432]
#  Distance to server: 18503.26m away.
#  Distance away: 5771.40m.
#  New broadcast distance: 6348m
#
# Node [21046, 8008]: data has been broadcast.
#
# Node [16400, 11432]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [16400, 11432] <<
#   Distance to server: 18503.26m
#
# Node [16400, 11432]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [15962, 15117]
#  Distance to server: 16692.19m away.
#  Distance away: 3710.94m.
#  New broadcast distance: 4082m
#
# Node [16400, 11432]: data has been broadcast.
#
# Node [15962, 15117]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [15962, 15117] <<
#   Distance to server: 16692.19m
#
# Node [15962, 15117]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [15962, 15117]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [15962, 15117]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
#
# Node [15962, 15117]: sending broadcast request . . .
# Broadcast distance: 15000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [4188, 22078]
#  Distance to server: 4675.19m away.
#  Distance away: 13677.81m.
#  New broadcast distance: 15045m
#
# Node [15962, 15117]: data has been broadcast.
#
# Node [4188, 22078]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [4188, 22078] <<
#   Distance to server: 4675.19m
#
# Node [4188, 22078]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [0, 20000.0]
#  Distance to server: 0.00m away.
#  Distance away: 4675.19m.
#  New broadcast distance: 5142m
#
# Node [4188, 22078]: data has been broadcast.
#
#
# SERVER: package successfully received.
#
#  Data: 12345
#
#  -- ENDING SIMULATION --.
#
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [27659, 37401] <<
#   Distance to server: 32677.44m
#
# Node [27659, 37401]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [26209, 34316]
#  Distance to server: 29864.02m away.
#  Distance away: 3408.77m.
#  New broadcast distance: 3749m
#
# Node [27659, 37401]: data has been broadcast.
#
# Node [26209, 34316]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [26209, 34316] <<
#   Distance to server: 29864.02m
#
# Node [26209, 34316]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [26209, 34316]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [17940, 34907]
#  Distance to server: 23325.14m away.
#  Distance away: 8290.09m.
#  New broadcast distance: 9119m
#
# Node [26209, 34316]: data has been broadcast.
#
# Node [17940, 34907]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [17940, 34907] <<
#   Distance to server: 23325.14m
#
# Node [17940, 34907]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [17940, 34907]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [17940, 34907]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [7122, 31037]
#  Distance to server: 13135.38m away.
#  Distance away: 11489.39m.
#  New broadcast distance: 12638m
#
# Node [17940, 34907]: data has been broadcast.
#
# Node [7122, 31037]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [7122, 31037] <<
#   Distance to server: 13135.38m
#
# Node [7122, 31037]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [7122, 31037]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [7122, 31037]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [10044, 20726]
#  Distance to server: 10070.20m away.
#  Distance away: 10717.03m.
#  New broadcast distance: 11788m
#
# Node [7122, 31037]: data has been broadcast.
#
# Node [10044, 20726]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [10044, 20726] <<
#   Distance to server: 10070.20m
#
# Node [10044, 20726]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [10044, 20726]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [10044, 20726]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [0, 20000.0]
#  Distance to server: 0.00m away.
#  Distance away: 10070.20m.
#  New broadcast distance: 11077m
#
# Node [10044, 20726]: data has been broadcast.
#
#
# SERVER: package successfully received.
#
#  Data: 12345
#
#  -- ENDING SIMULATION --.
#
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [29302, 33981] <<
#   Distance to server: 32466.53m
#
# Node [29302, 33981]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [29302, 33981]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [29302, 33981]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [18945, 29490]
#  Distance to server: 21188.99m away.
#  Distance away: 11288.78m.
#  New broadcast distance: 12417m
#
# Node [29302, 33981]: data has been broadcast.
#
# Node [18945, 29490]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [18945, 29490] <<
#   Distance to server: 21188.99m
#
# Node [18945, 29490]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [13566, 27847]
#  Distance to server: 15672.01m away.
#  Distance away: 5624.33m.
#  New broadcast distance: 6186m
#
# Node [18945, 29490]: data has been broadcast.
#
# Node [13566, 27847]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [13566, 27847] <<
#   Distance to server: 15672.01m
#
# Node [13566, 27847]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [13052, 23980]
#  Distance to server: 13645.33m away.
#  Distance away: 3901.01m.
#  New broadcast distance: 4291m
#
# Node [13566, 27847]: data has been broadcast.
#
# Node [13052, 23980]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [13052, 23980] <<
#   Distance to server: 13645.33m
#
# Node [13052, 23980]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [13052, 23980]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [13052, 23980]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [3635, 23244]
#  Distance to server: 4872.04m away.
#  Distance away: 9445.72m.
#  New broadcast distance: 10390m
#
# Node [13052, 23980]: data has been broadcast.
#
# Node [3635, 23244]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [3635, 23244] <<
#   Distance to server: 4872.04m
#
# Node [3635, 23244]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [0, 20000.0]
#  Distance to server: 0.00m away.
#  Distance away: 4872.04m.
#  New broadcast distance: 5359m
#
# Node [3635, 23244]: data has been broadcast.
#
#
# SERVER: package successfully received.
#
#  Data: 12345
#
#  -- ENDING SIMULATION --.
#
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [23555, 5774] <<
#   Distance to server: 27517.58m
#
# Node [23555, 5774]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [20820, 6270]
#  Distance to server: 24939.63m away.
#  Distance away: 2779.61m.
#  New broadcast distance: 3057m
#
# Node [23555, 5774]: data has been broadcast.
#
# Node [20820, 6270]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [20820, 6270] <<
#   Distance to server: 24939.63m
#
# Node [20820, 6270]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [20820, 6270]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [20820, 6270]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [11603, 4565]
#  Distance to server: 19309.81m away.
#  Distance away: 9373.37m.
#  New broadcast distance: 10310m
#
# Node [20820, 6270]: data has been broadcast.
#
# Node [11603, 4565]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [11603, 4565] <<
#   Distance to server: 19309.81m
#
# Node [11603, 4565]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [8612, 4936]
#  Distance to server: 17351.96m away.
#  Distance away: 3013.92m.
#  New broadcast distance: 3315m
#
# Node [11603, 4565]: data has been broadcast.
#
# Node [8612, 4936]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [8612, 4936] <<
#   Distance to server: 17351.96m
#
# Node [8612, 4936]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [8612, 4936]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [8612, 4936]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [912, 12768]
#  Distance to server: 7289.28m away.
#  Distance away: 10983.18m.
#  New broadcast distance: 12081m
#
# Node [8612, 4936]: data has been broadcast.
#
# Node [912, 12768]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [912, 12768] <<
#   Distance to server: 7289.28m
#
# Node [912, 12768]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [912, 12768]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [0, 20000.0]
#  Distance to server: 0.00m away.
#  Distance away: 7289.28m.
#  New broadcast distance: 8018m
#
# Node [912, 12768]: data has been broadcast.
#
#
# SERVER: package successfully received.
#
#  Data: 12345
#
#  -- ENDING SIMULATION --.
#
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [28849, 23367] <<
#   Distance to server: 29044.82m
#
# Node [28849, 23367]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [28849, 23367]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [28849, 23367]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [22934, 31016]
#  Distance to server: 25442.50m away.
#  Distance away: 9669.25m.
#  New broadcast distance: 10636m
#
# Node [28849, 23367]: data has been broadcast.
#
# Node [22934, 31016]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [22934, 31016] <<
#   Distance to server: 25442.50m
#
# Node [22934, 31016]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [18216, 32396]
#  Distance to server: 22033.69m away.
#  Distance away: 4915.68m.
#  New broadcast distance: 5407m
#
# Node [22934, 31016]: data has been broadcast.
#
# Node [18216, 32396]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [18216, 32396] <<
#   Distance to server: 22033.69m
#
# Node [18216, 32396]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [18216, 32396]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [18216, 32396]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
#
# Node [18216, 32396]: sending broadcast request . . .
# Broadcast distance: 15000m
#
# (Idle nodes run.)
#
#
# Node [18216, 32396]: sending broadcast request . . .
# Broadcast distance: 18000m
#
# (Idle nodes run.)
#
#
# Node [18216, 32396]: sending broadcast request . . .
# Broadcast distance: 21000m
#
# (Idle nodes run.)
#
#
# Node [18216, 32396]: sending broadcast request . . .
# Broadcast distance: 24000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [0, 20000.0]
#  Distance to server: 0.00m away.
#  Distance away: 22033.69m.
#  New broadcast distance: 24237m
#
# Node [18216, 32396]: data has been broadcast.
#
#
# SERVER: package successfully received.
#
#  Data: 12345
#
#  -- ENDING SIMULATION --.
#
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [25175, 24407] <<
#   Distance to server: 25557.82m
#
# Node [25175, 24407]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [25175, 24407]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [25175, 24407]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [14633, 25148]
#  Distance to server: 15512.14m away.
#  Distance away: 10568.01m.
#  New broadcast distance: 11624m
#
# Node [25175, 24407]: data has been broadcast.
#
# Node [14633, 25148]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [14633, 25148] <<
#   Distance to server: 15512.14m
#
# Node [14633, 25148]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [11067, 27567]
#  Distance to server: 13406.64m away.
#  Distance away: 4309.05m.
#  New broadcast distance: 4739m
#
# Node [14633, 25148]: data has been broadcast.
#
# Node [11067, 27567]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [11067, 27567] <<
#   Distance to server: 13406.64m
#
# Node [11067, 27567]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [5740, 28941]
#  Distance to server: 10624.93m away.
#  Distance away: 5501.35m.
#  New broadcast distance: 6051m
#
# Node [11067, 27567]: data has been broadcast.
#
# Node [5740, 28941]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [5740, 28941] <<
#   Distance to server: 10624.93m
#
# Node [5740, 28941]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [4332, 24928]
#  Distance to server: 6561.36m away.
#  Distance away: 4252.84m.
#  New broadcast distance: 4678m
#
# Node [5740, 28941]: data has been broadcast.
#
# Node [4332, 24928]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [4332, 24928] <<
#   Distance to server: 6561.36m
#
# Node [4332, 24928]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [4332, 24928]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [0, 20000.0]
#  Distance to server: 0.00m away.
#  Distance away: 6561.36m.
#  New broadcast distance: 7217m
#
# Node [4332, 24928]: data has been broadcast.
#
#
# SERVER: package successfully received.
#
#  Data: 12345
#
#  -- ENDING SIMULATION --.
#
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [29598, 33329] <<
#   Distance to server: 32460.80m
#
# Node [29598, 33329]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [26121, 35721]
#  Distance to server: 30486.99m away.
#  Distance away: 4220.33m.
#  New broadcast distance: 4642m
#
# Node [29598, 33329]: data has been broadcast.
#
# Node [26121, 35721]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [26121, 35721] <<
#   Distance to server: 30486.99m
#
# Node [26121, 35721]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [26121, 35721]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [18408, 37023]
#  Distance to server: 25072.63m away.
#  Distance away: 7822.12m.
#  New broadcast distance: 8604m
#
# Node [26121, 35721]: data has been broadcast.
#
# Node [18408, 37023]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [18408, 37023] <<
#   Distance to server: 25072.63m
#
# Node [18408, 37023]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [16273, 37866]
#  Distance to server: 24166.18m away.
#  Distance away: 2295.40m.
#  New broadcast distance: 2524m
#
# Node [18408, 37023]: data has been broadcast.
#
# Node [16273, 37866]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [16273, 37866] <<
#   Distance to server: 24166.18m
#
# Node [16273, 37866]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [16273, 37866]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [16273, 37866]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [7218, 39766]
#  Distance to server: 21042.68m away.
#  Distance away: 9252.19m.
#  New broadcast distance: 10177m
#
# Node [16273, 37866]: data has been broadcast.
#
# Node [7218, 39766]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [7218, 39766] <<
#   Distance to server: 21042.68m
#
# Node [7218, 39766]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [7218, 39766]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [7218, 39766]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
#
# Node [7218, 39766]: sending broadcast request . . .
# Broadcast distance: 15000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [7983, 25399]
#  Distance to server: 9637.30m away.
#  Distance away: 14387.35m.
#  New broadcast distance: 15826m
#
# Node [7218, 39766]: data has been broadcast.
#
# Node [7983, 25399]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [7983, 25399] <<
#   Distance to server: 9637.30m
#
# Node [7983, 25399]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [7983, 25399]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [7983, 25399]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [0, 20000.0]
#  Distance to server: 0.00m away.
#  Distance away: 9637.30m.
#  New broadcast distance: 10601m
#
# Node [7983, 25399]: data has been broadcast.
#
#
# SERVER: package successfully received.
#
#  Data: 12345
#
#  -- ENDING SIMULATION --.
#
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [35320, 27404] <<
#   Distance to server: 36087.69m
#
# Node [35320, 27404]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [30214, 28437]
#  Distance to server: 31369.87m away.
#  Distance away: 5209.45m.
#  New broadcast distance: 5730m
#
# Node [35320, 27404]: data has been broadcast.
#
# Node [30214, 28437]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [30214, 28437] <<
#   Distance to server: 31369.87m
#
# Node [30214, 28437]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [26042, 32333]
#  Distance to server: 28814.73m away.
#  Distance away: 5708.27m.
#  New broadcast distance: 6279m
#
# Node [30214, 28437]: data has been broadcast.
#
# Node [26042, 32333]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [26042, 32333] <<
#   Distance to server: 28814.73m
#
# Node [26042, 32333]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [26042, 32333]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [26042, 32333]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
#
# Node [26042, 32333]: sending broadcast request . . .
# Broadcast distance: 15000m
#
# (Idle nodes run.)
#
#
# Node [26042, 32333]: sending broadcast request . . .
# Broadcast distance: 18000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [23231, 16754]
#  Distance to server: 23456.68m away.
#  Distance away: 15830.57m.
#  New broadcast distance: 17413m
#
# Node [26042, 32333]: data has been broadcast.
#
# Node [23231, 16754]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [23231, 16754] <<
#   Distance to server: 23456.68m
#
# Node [23231, 16754]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [23231, 16754]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [23231, 16754]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [11401, 16941]
#  Distance to server: 11804.25m away.
#  Distance away: 11831.48m.
#  New broadcast distance: 13014m
#
# Node [23231, 16754]: data has been broadcast.
#
# Node [11401, 16941]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [11401, 16941] <<
#   Distance to server: 11804.25m
#
# Node [11401, 16941]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [11401, 16941]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [4029, 12617]
#  Distance to server: 8410.80m away.
#  Distance away: 8546.54m.
#  New broadcast distance: 9401m
#
# Node [11401, 16941]: data has been broadcast.
#
# Node [4029, 12617]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [4029, 12617] <<
#   Distance to server: 8410.80m
#
# Node [4029, 12617]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [1781, 14466]
#  Distance to server: 5813.53m away.
#  Distance away: 2910.72m.
#  New broadcast distance: 3201m
#
# Node [4029, 12617]: data has been broadcast.
#
# Node [1781, 14466]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [1781, 14466] <<
#   Distance to server: 5813.53m
#
# Node [1781, 14466]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [0, 20000.0]
#  Distance to server: 0.00m away.
#  Distance away: 5813.53m.
#  New broadcast distance: 6394m
#
# Node [1781, 14466]: data has been broadcast.
#
#
# SERVER: package successfully received.
#
#  Data: 12345
#
#  -- ENDING SIMULATION --.
#
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [26184, 23458] <<
#   Distance to server: 26411.35m
#
# Node [26184, 23458]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [22162, 25513]
#  Distance to server: 22837.41m away.
#  Distance away: 4516.58m.
#  New broadcast distance: 4968m
#
# Node [26184, 23458]: data has been broadcast.
#
# Node [22162, 25513]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [22162, 25513] <<
#   Distance to server: 22837.41m
#
# Node [22162, 25513]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [22162, 25513]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [16262, 21127]
#  Distance to server: 16301.01m away.
#  Distance away: 7351.67m.
#  New broadcast distance: 8086m
#
# Node [22162, 25513]: data has been broadcast.
#
# Node [16262, 21127]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [16262, 21127] <<
#   Distance to server: 16301.01m
#
# Node [16262, 21127]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [16262, 21127]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [8108, 23218]
#  Distance to server: 8723.26m away.
#  Distance away: 8417.84m.
#  New broadcast distance: 9259m
#
# Node [16262, 21127]: data has been broadcast.
#
# Node [8108, 23218]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [8108, 23218] <<
#   Distance to server: 8723.26m
#
# Node [8108, 23218]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [3783, 23484]
#  Distance to server: 5142.89m away.
#  Distance away: 4333.17m.
#  New broadcast distance: 4766m
#
# Node [8108, 23218]: data has been broadcast.
#
# Node [3783, 23484]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [3783, 23484] <<
#   Distance to server: 5142.89m
#
# Node [3783, 23484]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [0, 20000.0]
#  Distance to server: 0.00m away.
#  Distance away: 5142.89m.
#  New broadcast distance: 5657m
#
# Node [3783, 23484]: data has been broadcast.
#
#
# SERVER: package successfully received.
#
#  Data: 12345
#
#  -- ENDING SIMULATION --.
#
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [30580, 15543] <<
#   Distance to server: 30903.09m
#
# Node [30580, 15543]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [30580, 15543]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [25140, 22451]
#  Distance to server: 25259.20m away.
#  Distance away: 8792.84m.
#  New broadcast distance: 9672m
#
# Node [30580, 15543]: data has been broadcast.
#
# Node [25140, 22451]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [25140, 22451] <<
#   Distance to server: 25259.20m
#
# Node [25140, 22451]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [23788, 24263]
#  Distance to server: 24166.96m away.
#  Distance away: 2260.81m.
#  New broadcast distance: 2486m
#
# Node [25140, 22451]: data has been broadcast.
#
# Node [23788, 24263]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [23788, 24263] <<
#   Distance to server: 24166.96m
#
# Node [23788, 24263]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [18104, 22358]
#  Distance to server: 18256.92m away.
#  Distance away: 5994.74m.
#  New broadcast distance: 6594m
#
# Node [23788, 24263]: data has been broadcast.
#
# Node [18104, 22358]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [18104, 22358] <<
#   Distance to server: 18256.92m
#
# Node [18104, 22358]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [14585, 22751]
#  Distance to server: 14842.18m away.
#  Distance away: 3540.88m.
#  New broadcast distance: 3894m
#
# Node [18104, 22358]: data has been broadcast.
#
# Node [14585, 22751]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [14585, 22751] <<
#   Distance to server: 14842.18m
#
# Node [14585, 22751]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [14585, 22751]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [6363, 21571]
#  Distance to server: 6554.07m away.
#  Distance away: 8306.24m.
#  New broadcast distance: 9136m
#
# Node [14585, 22751]: data has been broadcast.
#
# Node [6363, 21571]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [6363, 21571] <<
#   Distance to server: 6554.07m
#
# Node [6363, 21571]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [6363, 21571]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [0, 20000.0]
#  Distance to server: 0.00m away.
#  Distance away: 6554.07m.
#  New broadcast distance: 7209m
#
# Node [6363, 21571]: data has been broadcast.
#
#
# SERVER: package successfully received.
#
#  Data: 12345
#
#  -- ENDING SIMULATION --.
#
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [28901, 22217] <<
#   Distance to server: 28985.91m
#
# Node [28901, 22217]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [25871, 23881]
#  Distance to server: 26160.48m away.
#  Distance away: 3456.85m.
#  New broadcast distance: 3802m
#
# Node [28901, 22217]: data has been broadcast.
#
# Node [25871, 23881]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [25871, 23881] <<
#   Distance to server: 26160.48m
#
# Node [25871, 23881]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [25871, 23881]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [25871, 23881]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [16368, 17871]
#  Distance to server: 16505.88m away.
#  Distance away: 11243.98m.
#  New broadcast distance: 12368m
#
# Node [25871, 23881]: data has been broadcast.
#
# Node [16368, 17871]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [16368, 17871] <<
#   Distance to server: 16505.88m
#
# Node [16368, 17871]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [16368, 17871]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [16368, 17871]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
#
# Node [16368, 17871]: sending broadcast request . . .
# Broadcast distance: 15000m
#
# (Idle nodes run.)
#
#
# Node [16368, 17871]: sending broadcast request . . .
# Broadcast distance: 18000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [0, 20000.0]
#  Distance to server: 0.00m away.
#  Distance away: 16505.88m.
#  New broadcast distance: 18156m
#
# Node [16368, 17871]: data has been broadcast.
#
#
# SERVER: package successfully received.
#
#  Data: 12345
#
#  -- ENDING SIMULATION --.
#
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [23455, 2756] <<
#   Distance to server: 29111.73m
#
# Node [23455, 2756]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [18258, 3588]
#  Distance to server: 24550.12m away.
#  Distance away: 5263.18m.
#  New broadcast distance: 5789m
#
# Node [23455, 2756]: data has been broadcast.
#
# Node [18258, 3588]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [18258, 3588] <<
#   Distance to server: 24550.12m
#
# Node [18258, 3588]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [18258, 3588]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [9761, 3533]
#  Distance to server: 19142.60m away.
#  Distance away: 8497.18m.
#  New broadcast distance: 9346m
#
# Node [18258, 3588]: data has been broadcast.
#
# Node [9761, 3533]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [9761, 3533] <<
#   Distance to server: 19142.60m
#
# Node [9761, 3533]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [5365, 2798]
#  Distance to server: 18019.21m away.
#  Distance away: 4457.02m.
#  New broadcast distance: 4902m
#
# Node [9761, 3533]: data has been broadcast.
#
# Node [5365, 2798]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [5365, 2798] <<
#   Distance to server: 18019.21m
#
# Node [5365, 2798]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [5365, 2798]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [5073, 9767]
#  Distance to server: 11421.45m away.
#  Distance away: 6975.11m.
#  New broadcast distance: 7672m
#
# Node [5365, 2798]: data has been broadcast.
#
# Node [5073, 9767]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [5073, 9767] <<
#   Distance to server: 11421.45m
#
# Node [5073, 9767]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [2341, 12702]
#  Distance to server: 7664.27m away.
#  Distance away: 4009.74m.
#  New broadcast distance: 4410m
#
# Node [5073, 9767]: data has been broadcast.
#
# Node [2341, 12702]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [2341, 12702] <<
#   Distance to server: 7664.27m
#
# Node [2341, 12702]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [2341, 12702]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [0, 20000.0]
#  Distance to server: 0.00m away.
#  Distance away: 7664.27m.
#  New broadcast distance: 8430m
#
# Node [2341, 12702]: data has been broadcast.
#
#
# SERVER: package successfully received.
#
#  Data: 12345
#
#  -- ENDING SIMULATION --.
#
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [33679, 19481] <<
#   Distance to server: 33683.00m
#
# Node [33679, 19481]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [33679, 19481]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [33679, 19481]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [22676, 23367]
#  Distance to server: 22924.61m away.
#  Distance away: 11669.06m.
#  New broadcast distance: 12835m
#
# Node [33679, 19481]: data has been broadcast.
#
# Node [22676, 23367]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [22676, 23367] <<
#   Distance to server: 22924.61m
#
# Node [22676, 23367]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [22676, 23367]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [16505, 20811]
#  Distance to server: 16524.91m away.
#  Distance away: 6679.40m.
#  New broadcast distance: 7347m
#
# Node [22676, 23367]: data has been broadcast.
#
# Node [16505, 20811]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [16505, 20811] <<
#   Distance to server: 16524.91m
#
# Node [16505, 20811]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [13284, 16116]
#  Distance to server: 13840.16m away.
#  Distance away: 5693.67m.
#  New broadcast distance: 6263m
#
# Node [16505, 20811]: data has been broadcast.
#
# Node [13284, 16116]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [13284, 16116] <<
#   Distance to server: 13840.16m
#
# Node [13284, 16116]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [13284, 16116]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [5660, 12867]
#  Distance to server: 9105.78m away.
#  Distance away: 8287.42m.
#  New broadcast distance: 9116m
#
# Node [13284, 16116]: data has been broadcast.
#
# Node [5660, 12867]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [5660, 12867] <<
#   Distance to server: 9105.78m
#
# Node [5660, 12867]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [5660, 12867]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [5660, 12867]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [0, 20000.0]
#  Distance to server: 0.00m away.
#  Distance away: 9105.78m.
#  New broadcast distance: 10016m
#
# Node [5660, 12867]: data has been broadcast.
#
#
# SERVER: package successfully received.
#
#  Data: 12345
#
#  -- ENDING SIMULATION --.
#
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [22228, 26737] <<
#   Distance to server: 23226.52m
#
# Node [22228, 26737]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [22228, 26737]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
#
# Node [22228, 26737]: sending broadcast request . . .
# Broadcast distance: 12000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [18358, 16820]
#  Distance to server: 18631.39m away.
#  Distance away: 10645.36m.
#  New broadcast distance: 11709m
#
# Node [22228, 26737]: data has been broadcast.
#
# Node [18358, 16820]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [18358, 16820] <<
#   Distance to server: 18631.39m
#
# Node [18358, 16820]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
#
# Node [18358, 16820]: sending broadcast request . . .
# Broadcast distance: 9000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [10688, 17770]
#  Distance to server: 10918.16m away.
#  Distance away: 7728.61m.
#  New broadcast distance: 8501m
#
# Node [18358, 16820]: data has been broadcast.
#
# Node [10688, 17770]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [10688, 17770] <<
#   Distance to server: 10918.16m
#
# Node [10688, 17770]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [7183, 22389]
#  Distance to server: 7569.86m away.
#  Distance away: 5798.29m.
#  New broadcast distance: 6378m
#
# Node [10688, 17770]: data has been broadcast.
#
# Node [7183, 22389]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [7183, 22389] <<
#   Distance to server: 7569.86m
#
# Node [7183, 22389]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [4432, 20399]
#  Distance to server: 4449.92m away.
#  Distance away: 3395.31m.
#  New broadcast distance: 3734m
#
# Node [7183, 22389]: data has been broadcast.
#
# Node [4432, 20399]: package successfully received.
#
# (Idle nodes run.)
#
#
#  >> New Broadcast Node: [4432, 20399] <<
#   Distance to server: 4449.92m
#
# Node [4432, 20399]: sending broadcast request . . .
# Broadcast distance: 6000m
#
# (Idle nodes run.)
#
# RECEIVER NODE SELECTED!:
#  Location: [0, 20000.0]
#  Distance to server: 0.00m away.
#  Distance away: 4449.92m.
#  New broadcast distance: 4894m
#
# Node [4432, 20399]: data has been broadcast.
#
#
# SERVER: package successfully received.
#
#  Data: 12345
#
#  -- ENDING SIMULATION --.
#
#
# (Idle nodes run.)
#
# TOTALS:
# Simulation 0:
# Unadjusted broadcast length: 57000.00
# Adjusted broadcast length: 52621.30
# Actual route length: 47837.55
# Simulation 1:
# Unadjusted broadcast length: 39000.00
# Adjusted broadcast length: 34338.35
# Actual route length: 31216.68
# Simulation 2:
# Unadjusted broadcast length: 33000.00
# Adjusted broadcast length: 30618.88
# Actual route length: 27835.35
# Simulation 3:
# Unadjusted broadcast length: 51000.00
# Adjusted broadcast length: 48373.04
# Actual route length: 43975.49
# Simulation 4:
# Unadjusted broadcast length: 42000.00
# Adjusted broadcast length: 38645.06
# Actual route length: 35131.88
# Simulation 5:
# Unadjusted broadcast length: 45000.00
# Adjusted broadcast length: 36783.30
# Actual route length: 33439.36
# Simulation 6:
# Unadjusted broadcast length: 42000.00
# Adjusted broadcast length: 40280.48
# Actual route length: 36618.62
# Simulation 7:
# Unadjusted broadcast length: 39000.00
# Adjusted broadcast length: 34311.86
# Actual route length: 31192.60
# Simulation 8:
# Unadjusted broadcast length: 60000.00
# Adjusted broadcast length: 52376.16
# Actual route length: 47614.69
# Simulation 9:
# Unadjusted broadcast length: 63000.00
# Adjusted broadcast length: 61435.62
# Actual route length: 55850.56
# Simulation 10:
# Unadjusted broadcast length: 36000.00
# Adjusted broadcast length: 32738.37
# Actual route length: 29762.15
# Simulation 11:
# Unadjusted broadcast length: 45000.00
# Adjusted broadcast length: 38994.53
# Actual route length: 35449.58
# Simulation 12:
# Unadjusted broadcast length: 36000.00
# Adjusted broadcast length: 34327.38
# Actual route length: 31206.71
# Simulation 13:
# Unadjusted broadcast length: 45000.00
# Adjusted broadcast length: 40553.16
# Actual route length: 36866.51
# Simulation 14:
# Unadjusted broadcast length: 48000.00
# Adjusted broadcast length: 45578.87
# Actual route length: 41435.34
# Simulation 15:
# Unadjusted broadcast length: 39000.00
# Adjusted broadcast length: 35219.24
# Actual route length: 32017.50

# %%
############# 
# PLOT DATA #
#############

x_vals = list(range(16*6))
y_vals_unadj = [0]*16*6
y_vals_adj = [0]*16*6
y_vals_routes = [0]*16*6


for i in range(16):
  j = i*6 + 1 
  k = i*6 + 2
  l = i*6 + 3
  
  y_vals_unadj[j] = sim_totals_broadcast_unadj[i]
  y_vals_adj[k] = sim_totals_broadcast_adj[i]
  y_vals_routes[l] = sim_totals_routes[i]


fig, ax = plt.subplots(figsize=(12, 8))
ax.bar(x_vals, y_vals_unadj)
ax.bar(x_vals, y_vals_adj)
ax.bar(x_vals, y_vals_routes)
ax.legend(['Unadjusted broadcast distance', 'Adjusted broadcast distance', 'True route length'])
ax.legend(['Unadjusted broadcast distance', 'Adjusted broadcast distance', 'True route length'])
fig.suptitle('16 Simulations of Power-Adjusted Geographic Routing')

# save results
if True: 
  filename = 'ELEC5514_summary_data.png'
  plt.savefig(filename)
  files.download(filename)

# PRINT FULL RAW DATA
if False:
  for i in range(len(all_sim_distances_unadj)):
    print(all_sim_distances_unadj[i])
    print(all_sim_distances_adj[i])
    print(all_sim_route_distances[i])
